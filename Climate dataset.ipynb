# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_excel("C:\pydatafiles\spd_crime Seattle.xlsx")
df
# Out:
#      Report Number   Offense ID  Offense Start DateTime  \
# 0      2020-044620  12605873663  02/05/2020 10:10:00 AM
# 1      2020-044452  12605598696  02/03/2020 08:00:00 AM
# 2      2020-044465  12605567653  02/02/2020 08:30:00 PM
# 3      2020-044225  12605174036  02/05/2020 01:17:00 AM
# 4      2020-044076  12605081469  02/05/2020 12:51:21 AM
# ...            ...          ...                     ...
# 1494   2020-023839  12174626452  01/20/2020 06:07:00 PM
# 1495   2020-023785  12174618231  01/20/2020 04:30:00 PM
# 1496   2020-023781  12174602509  01/20/2020 05:10:00 PM
# 1497   2020-023762  12174603074  01/20/2020 03:00:00 PM
# 1498   2020-023666  12174611153  01/20/2020 03:29:00 PM
#
#         Offense End DateTime         Report DateTime Group A B  \
# 0                        NaN  02/05/2020 11:24:31 AM         A
# 1     02/04/2020 08:00:00 AM  02/05/2020 10:06:28 AM         A
# 2     02/02/2020 09:30:00 PM  02/05/2020 09:39:33 AM         A
# ...

# %% [markdown]
# # Use DataFrame.iloc[] to drop first row.
# # Example 1: Use DataFrame.iloc[] to drop first row
# df1 = df.iloc[1:]
#
# # Example 2: Use DataFrame.drop() function to delete first row
# df.drop(index=df.index[0], axis=0, inplace=True)
#
# # Example 3:  Use DataFrame.tail() method to drop first row
# df1 = df.tail(-1)

# %%
df=df.iloc[1:]

# %%
df
# Out:
#      Report Number   Offense ID  Offense Start DateTime  \
# 1      2020-044452  12605598696  02/03/2020 08:00:00 AM
# 2      2020-044465  12605567653  02/02/2020 08:30:00 PM
# 3      2020-044225  12605174036  02/05/2020 01:17:00 AM
# 4      2020-044076  12605081469  02/05/2020 12:51:21 AM
# 5      2020-044142  12605077150  02/04/2020 10:59:00 PM
# ...            ...          ...                     ...
# 1494   2020-023839  12174626452  01/20/2020 06:07:00 PM
# 1495   2020-023785  12174618231  01/20/2020 04:30:00 PM
# 1496   2020-023781  12174602509  01/20/2020 05:10:00 PM
# 1497   2020-023762  12174603074  01/20/2020 03:00:00 PM
# 1498   2020-023666  12174611153  01/20/2020 03:29:00 PM
#
#         Offense End DateTime         Report DateTime Group A B  \
# 1     02/04/2020 08:00:00 AM  02/05/2020 10:06:28 AM         A
# 2     02/02/2020 09:30:00 PM  02/05/2020 09:39:33 AM         A
# 3     02/05/2020 02:21:00 AM  02/05/2020 03:30:55 AM         A
# ...

# %%
df.head()
# Out:
#   Report Number   Offense ID  Offense Start DateTime    Offense End DateTime  \
# 1   2020-044452  12605598696  02/03/2020 08:00:00 AM  02/04/2020 08:00:00 AM
# 2   2020-044465  12605567653  02/02/2020 08:30:00 PM  02/02/2020 09:30:00 PM
# 3   2020-044225  12605174036  02/05/2020 01:17:00 AM  02/05/2020 02:21:00 AM
# 4   2020-044076  12605081469  02/05/2020 12:51:21 AM                     NaN
# 5   2020-044142  12605077150  02/04/2020 10:59:00 PM                     NaN
#
#           Report DateTime Group A B Crime Against Category  \
# 1  02/05/2020 10:06:28 AM         A               PROPERTY
# 2  02/05/2020 09:39:33 AM         A               PROPERTY
# 3  02/05/2020 03:30:55 AM         A               PROPERTY
# 4  02/05/2020 12:51:31 AM         B                SOCIETY
# 5  02/05/2020 12:45:08 AM         A               PROPERTY
#
#                        Offense Parent Group  \
# 1                             LARCENY-THEFT
# 2                                   ROBBERY
# ...

# %%
df.tail()
# Out:
#      Report Number   Offense ID  Offense Start DateTime  \
# 1494   2020-023839  12174626452  01/20/2020 06:07:00 PM
# 1495   2020-023785  12174618231  01/20/2020 04:30:00 PM
# 1496   2020-023781  12174602509  01/20/2020 05:10:00 PM
# 1497   2020-023762  12174603074  01/20/2020 03:00:00 PM
# 1498   2020-023666  12174611153  01/20/2020 03:29:00 PM
#
#         Offense End DateTime         Report DateTime Group A B  \
# 1494                     NaN  01/20/2020 06:32:10 PM         A
# 1495                     NaN  01/20/2020 06:19:50 PM         A
# 1496                     NaN  01/20/2020 05:57:26 PM         A
# 1497  01/20/2020 05:00:00 PM  01/20/2020 05:53:39 PM         A
# 1498  01/20/2020 03:29:00 PM  01/20/2020 05:49:40 PM         A
#
#      Crime Against Category Offense Parent Group  \
# 1494               PROPERTY        LARCENY-THEFT
# 1495               PROPERTY        LARCENY-THEFT
# 1496               PROPERTY       FRAUD OFFENSES
# ...

# %%
df.describe()
# Out:
#          Offense ID    Longitude     Latitude
# count  1.498000e+03  1498.000000  1498.000000
# mean   1.238151e+10  -120.374116    46.858715
# std    1.652659e+08    15.365115     5.981476
# min    1.217460e+10  -122.414924     0.000000
# 25%    1.222136e+10  -122.354328    47.590764
# 50%    1.233854e+10  -122.333167    47.615598
# 75%    1.259569e+10  -122.315470    47.663118
# max    1.260560e+10     0.000000    47.732139

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 1 to 1498
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Report Number           1498 non-null   object
#  1   Offense ID              1498 non-null   int64
#  2   Offense Start DateTime  1498 non-null   object
#  3   Offense End DateTime    1139 non-null   object
#  4   Report DateTime         1498 non-null   object
#  5   Group A B               1498 non-null   object
#  6   Crime Against Category  1498 non-null   object
#  7   Offense Parent Group    1498 non-null   object
#  8   Offense                 1498 non-null   object
#  9   Offense Code            1498 non-null   object
#  10  Precinct                1498 non-null   object
#  11  Sector                  1498 non-null   object
#  12  Beat                    1498 non-null   object
#  13  MCPP                    1498 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Report Number               0
# Offense ID                  0
# Offense Start DateTime      0
# Offense End DateTime      359
# Report DateTime             0
# Group A B                   0
# Crime Against Category      0
# Offense Parent Group        0
# Offense                     0
# Offense Code                0
# Precinct                    0
# Sector                      0
# Beat                        0
# MCPP                        0
# 100 Block Address          24
# Longitude                   0
# Latitude                    0
# dtype: int64

# %%
df.drop['Offense End DateTime']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df.drop['Offense End DateTime']
#
# TypeError: 'method' object is not subscriptable

# %%
df.isnull().sum()
# Out:
# Report Number               0
# Offense ID                  0
# Offense Start DateTime      0
# Offense End DateTime      359
# Report DateTime             0
# Group A B                   0
# Crime Against Category      0
# Offense Parent Group        0
# Offense                     0
# Offense Code                0
# Precinct                    0
# Sector                      0
# Beat                        0
# MCPP                        0
# 100 Block Address          24
# Longitude                   0
# Latitude                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Report Number', 'Offense ID', 'Offense Start DateTime',
#        'Offense End DateTime', 'Report DateTime', 'Group A B',
#        'Crime Against Category', 'Offense Parent Group', 'Offense',
#        'Offense Code', 'Precinct', 'Sector', 'Beat', 'MCPP',
#        '100 Block Address', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#      Report Number   Offense ID  Offense Start DateTime  \
# 1      2020-044452  12605598696  02/03/2020 08:00:00 AM
# 2      2020-044465  12605567653  02/02/2020 08:30:00 PM
# 3      2020-044225  12605174036  02/05/2020 01:17:00 AM
# 4      2020-044076  12605081469  02/05/2020 12:51:21 AM
# 5      2020-044142  12605077150  02/04/2020 10:59:00 PM
# ...            ...          ...                     ...
# 1494   2020-023839  12174626452  01/20/2020 06:07:00 PM
# 1495   2020-023785  12174618231  01/20/2020 04:30:00 PM
# 1496   2020-023781  12174602509  01/20/2020 05:10:00 PM
# 1497   2020-023762  12174603074  01/20/2020 03:00:00 PM
# 1498   2020-023666  12174611153  01/20/2020 03:29:00 PM
#
#         Offense End DateTime         Report DateTime Group A B  \
# 1     02/04/2020 08:00:00 AM  02/05/2020 10:06:28 AM         A
# 2     02/02/2020 09:30:00 PM  02/05/2020 09:39:33 AM         A
# 3     02/05/2020 02:21:00 AM  02/05/2020 03:30:55 AM         A
# ...

# %%
df.shape
# Out:
# (1498, 17)

# %%
df.dtypes
# Out:
# Report Number              object
# Offense ID                  int64
# Offense Start DateTime     object
# Offense End DateTime       object
# Report DateTime            object
# Group A B                  object
# Crime Against Category     object
# Offense Parent Group       object
# Offense                    object
# Offense Code               object
# Precinct                   object
# Sector                     object
# Beat                       object
# MCPP                       object
# 100 Block Address          object
# Longitude                 float64
# Latitude                  float64
# dtype: object

# %%
# heatmap 

plt.figure(figsize = (20, 12))

corr = df.corr()
sns.heatmap(corr, linewidths = 1, annot = True, fmt = ".2f")
plt.show()

# %%
fig = px.scatter(df, x=df.Year, y=df.Value)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 fig = px.scatter(df, x=df.Year, y=df.Value)
#       2 fig.show()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
fig = px.bar(df, x=df.Indicator_Name, y=df.Year,color=df.Value)
fig.show()

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
from dash import Dash, dcc, html, Input, Output

# %%
#Build An App

# %%
app =JupyterDash(_name_)
app.layout= html.Div([
    html.H1("Climate in Pakistan"),
    dcc.Graph(id='graph')
])
